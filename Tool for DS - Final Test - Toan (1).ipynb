# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Nguyen Manh Minh Toan__
# Data Scientist

# %% [markdown]
# _Data Science help me to see the insight of massive data set, which will benefit for my startup._

# %% [markdown]
# ### The next cell will calculate how old I am when my son finishes his Bachelor's course.

# %%
30 + 23
# Out:
# 53

# %% [markdown]
# ***

# %% [markdown]
# ![Mkutano.jpg](attachment:52fb5dc9-5a0f-46c5-856f-3d44425ebb74.jpg)

# %% [markdown]
# My bucket list:
# 1. Making a famous animation movie in 3D
# 2. Travel around the world for at least 100 con
